# %% [markdown]
# Ejercicio 1:
# Para empezar, después de la lectura he limpiado el DF de NaNs porque había un atributo con alguno (<1%).
#
# Después les he aplicado un Standard Scaling a las columnas de escalares que no representaban algo binario, a esas les he aplicado Label Encoding, y a las categóricas de más de dos tipos de categorías ha sido OHE.

# %% [markdown]
# Ejercicio 3:
# MLP de 3 capas: [128, 64, 32]
# MLP Accuracy for Lambda = 0.50000 : 0.84716
# MLP COMPLETE Confusion Matrix:
#  [[ 84  23]
#  [ 12 110]]
#
# MLP de 1 capa: [256]
# MLP Accuracy for Lambda = 0.50000 : 0.85590
# MLP COMPLETE Confusion Matrix:
#  [[ 89  18]
#  [ 15 107]]
#
# Y sus CM respectivamente:
#
# |        | predicted 0 | predicted 1 |
# | ----------- | ----------- | ----------- |
# | real 0 | TN | FP |
# | real 1 | FN | TP |
#
# El que menor tasa de FN ha tenido es el de 3 capas, así que escogería ese por motivos de salud, aunque haya tenido ligeramente menos accuracyc que el de 1 capa.

# %% [markdown]
# Ejercicio 5:
# SKLEARN MLP accuracy for lambda = 0.50000 : 0.84279
# KNN Accuracy: 0.86463
# Random Forest accuracy: 0.84279
# SKLEARN MLP LOGISTIC Confusion Matrix:
#  [[ 90  17]
#  [ 19 103]]
# MLP COMPLETE 1 Confusion Matrix:
#  [[ 84  23]
#  [ 12 110]]
# KNN Confusion Matrix:
#  [[ 88  19]
#  [ 12 110]]
# RANDOM FOREST Confusion Matrix:
#  [[ 84  23]
#  [ 13 109]]
#
#  Teniendo en cuenta que las matrices tienen este formato:
#  x -> predicted; y -> real
#  Significa que
# |        | predicted 0 | predicted 1 |
# | ----------- | ----------- | ----------- |
# | real 0 | TN | FP |
# | real 1 | FN | TP |
#
# El mayor peligro reside en los FN, al ser un ámbito sanitario. El MLP que los ha minimizado ha sido el nuestro de 1 capa, así que escogería ese si tuviera que escoger un MLP, pero al ser de caja negra tiraría por el KNN que es de caja gris y es mucho más simple e inmediato, ha tenido mejor accuracy y en general es más rectificable, fácilmente entrenable.
